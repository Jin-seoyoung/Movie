# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/run07/OneDrive/바탕 화면/영화 관객수/DATA/movies.csv')
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
all_movie = pd.read_csv('C:/Users/run07/OneDrive/바탕 화면/영화 관객수/DATA/movies.csv')

# %%
all_movie.shape
# Out:
# (600, 12)

# %%
all_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %%
all_movie.isna()
# isna(): 데이터프레임 내에 결측 값을 확인/그 결과를 True 또는 False로 반환
# Out:
#      title  distributor  genre  release_time   time  screening_rat  director  \
# 0    False        False  False         False  False          False     False
# 1    False        False  False         False  False          False     False
# 2    False        False  False         False  False          False     False
# 3    False        False  False         False  False          False     False
# 4    False        False  False         False  False          False     False
# ..     ...          ...    ...           ...    ...            ...       ...
# 595  False        False  False         False  False          False     False
# 596  False        False  False         False  False          False     False
# 597  False        False  False         False  False          False     False
# 598  False        False  False         False  False          False     False
# 599  False        False  False         False  False          False     False
#
# ...

# %%
all_movie.fillna(0)
# fillna(): 결측치를 다른값으로 대체 
# fillna(0): 결측치를 0 으로 대체
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
all_Movie = all_movie.fillna(0)

# %%
all_Movie.describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor  \
# count  600.000000    6.000000e+02    600.000000  600.000000  600.000000
# mean   100.863333    4.726993e+05      0.876667  151.118333    3.706667
# std     18.097528    1.309474e+06      1.183409  165.654671    2.446889
# min     45.000000    0.000000e+00      0.000000    0.000000    0.000000
# 25%     89.000000    0.000000e+00      0.000000   17.000000    2.000000
# 50%    100.000000    0.000000e+00      0.000000   82.500000    3.000000
# 75%    114.000000    3.761416e+05      2.000000  264.000000    4.000000
# max    180.000000    1.761531e+07      5.000000  869.000000   25.000000
#
#         box_off_num
# count  6.000000e+02
# mean   7.081818e+05
# std    1.828006e+06
# min    1.000000e+00
# 25%    1.297250e+03
# 50%    1.259100e+04
# 75%    4.798868e+05
# max    1.426277e+07

# %%
all_Movie[['genre', 'box_off_num']].groupby('genre').mean().sort_values('box_off_num')
# Out:
#          box_off_num
# genre
# 뮤지컬     6.627000e+03
# 다큐멘터리   6.717226e+04
# 서스펜스    8.261100e+04
# 애니메이션   1.819267e+05
# 멜로/로맨스  4.259680e+05
# 미스터리    5.275482e+05
# 공포      5.908325e+05
# 드라마     6.256898e+05
# 코미디     1.193914e+06
# SF      1.788346e+06
# 액션      2.203974e+06
# 느와르     2.263695e+06

# %%
all_Movie[['screening_rat', 'box_off_num']].groupby('screening_rat').mean().sort_values('box_off_num')
# Out:
#                 box_off_num
# screening_rat
# 전체 관람가         1.351005e+05
# 청소년 관람불가       3.641813e+05
# 12세 관람가        8.449809e+05
# 15세 관람가        1.247519e+06

# %%
all_Movie[['director', 'box_off_num']].groupby('director').mean().sort_values('box_off_num')
# Out:
#           box_off_num
# director
# 노성수               1.0
# 김정호               2.0
# 고구마               8.0
# 이세일              10.0
# 진광교              36.0
# ...               ...
# 한재림         9135806.0
# 봉준호         9350351.0
# 양우석        11374879.0
# 최동훈        12845252.0
# 윤제균        14262766.0
#
# [472 rows x 1 columns]

# %%
all_Movie[['distributor', 'box_off_num']].groupby('distributor').mean().sort_values('box_off_num')
# Out:
#                   box_off_num
# distributor
# 인피니티엔터테인먼트       2.000000e+00
# 고구마공작소           8.000000e+00
# 사람과 사람들          4.200000e+01
# 위드시네마            4.600000e+01
# 나우콘텐츠            5.400000e+01
# ...                       ...
# 영구아트무비           2.541603e+06
# 쇼박스(주)미디어플렉스     2.634823e+06
# (주)아이필름코퍼레이션     3.117859e+06
# (주)쇼박스           3.386656e+06
# CJ E&M Pictures  4.122337e+06
#
# [169 rows x 1 columns]

# %%
all_Movie['genre_num'] = all_Movie.genre.map({'뮤지컬':1, '다큐멘터리':2, '서스펜스':3, '애니메이션':4, '멜로/로맨스':5, '미스터리':6, 
                                              '공포':7, '드라마':8, '코미디':9, 'SF':10, '액션':11, '느와르':12})

# %%
dis_rank = all_Movie.groupby('distributor').box_off_num.median().reset_index(name = 'dis_rank_num').sort_values(by = 'dis_rank_num')
dis_rank
# Out:
#          distributor  dis_rank_num
# 141       인피니티엔터테인먼트           2.0
# 65            고구마공작소           8.0
# 92           사람과 사람들          42.0
# 131            위드시네마          46.0
# 68             나우콘텐츠          54.0
# ..               ...           ...
# 50       CJ E&M 영화부문     2242510.0
# 121           영구아트무비     2541603.0
# 96      쇼박스(주)미디어플렉스     2634823.0
# 27      (주)아이필름코퍼레이션     3117859.0
# 49   CJ E&M Pictures     4122337.0
#
# [169 rows x 2 columns]

# %%
dis_rank.shape[0]
# Out:
# 169

# %%
dis_rank['dis_rank_num'] = [i+1 for i in range(dis_rank.shape[0])]
dis_rank
# Out:
#          distributor  dis_rank_num
# 141       인피니티엔터테인먼트             1
# 65            고구마공작소             2
# 92           사람과 사람들             3
# 131            위드시네마             4
# 68             나우콘텐츠             5
# ..               ...           ...
# 50       CJ E&M 영화부문           165
# 121           영구아트무비           166
# 96      쇼박스(주)미디어플렉스           167
# 27      (주)아이필름코퍼레이션           168
# 49   CJ E&M Pictures           169
#
# [169 rows x 2 columns]

# %%
all_Movie = pd.merge(all_Movie, dis_rank, how='left')

# %%
all_Movie
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
all_Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  600 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
#  12  genre_num       600 non-null    int64
#  13  dis_rank_num    600 non-null    int64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 70.3+ KB

# %%
all_Movie.corr()
# Out:
#                     time  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# time            1.000000        0.266065      0.306727   0.623205   0.114153
# dir_prev_bfnum  0.266065        1.000000      0.396616   0.369657   0.042491
# dir_prev_num    0.306727        0.396616      1.000000   0.450706   0.014006
# num_staff       0.623205        0.369657      0.450706   1.000000   0.077871
# num_actor       0.114153        0.042491      0.014006   0.077871   1.000000
# box_off_num     0.441452        0.293791      0.259674   0.544265   0.111179
# genre_num       0.404035        0.174314      0.236391   0.466936   0.058944
# dis_rank_num    0.533877        0.250900      0.367591   0.664916   0.086059
#
#                 box_off_num  genre_num  dis_rank_num
# time               0.441452   0.404035      0.533877
# dir_prev_bfnum     0.293791   0.174314      0.250900
# dir_prev_num       0.259674   0.236391      0.367591
# num_staff          0.544265   0.466936      0.664916
# ...

# %%
import seaborn as sns

sns.heatmap(all_Movie.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test = train_test_split(X_movie, y_movie, random_state=0, test_size=0.2)

# %% [markdown]
# train, test = train_test_split(all_Movie, randdom_state=0, test_size=0.2)

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb

train, test = train_test_split(all_Movie, random_state=0, test_size=0.2)
model = lgb.LGBMRegressor(random_state=1234, n_estimators=1000)

features = ['time', 'dis_rank_num', 'num_staff']
target = ['box_off_num']
X_train, X_test, y_train, y_test = train[features], test[features], train[target], test[target]

# %%
X_train
# Out:
#      time  dis_rank_num  num_staff
# 118   103           166         31
# 362   135           164        462
# 55    120           164        279
# 90    132           155        379
# 390   115           134         49
# ..    ...           ...        ...
# 277    89            25         12
# 9      94            40        138
# 359    91            69          2
# 192   117           138        270
# 559   125           151        303
#
# [480 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

df1 = pd.DataFrame(X_train_scaled)
df1.to_csv('X_train_scaled.csv', index=False)

df2 = pd.DataFrame(X_test_scaled)
df2.to_csv('X_test_scaled.csv', index=False)

# %%
X_train_scaled = pd.read_csv('X_train_scaled.csv')
X_test_scaled = pd.read_csv('X_test_scaled.csv')

# %%
X_train_scaled
# Out:
#             0         1         2
# 0    0.429630  0.982143  0.035673
# 1    0.666667  0.970238  0.531646
# 2    0.555556  0.970238  0.321059
# 3    0.644444  0.916667  0.436133
# 4    0.518519  0.791667  0.056387
# ..        ...       ...       ...
# 475  0.325926  0.142857  0.013809
# 476  0.362963  0.232143  0.158803
# 477  0.340741  0.404762  0.002301
# 478  0.533333  0.815476  0.310702
# 479  0.592593  0.892857  0.348677
#
# [480 rows x 3 columns]

# %%
X_test_scaled
# Out:
#             0         1         2
# 0    0.673077  0.993464  0.614265
# 1    0.625000  0.954248  0.452693
# 2    0.346154  0.261438  0.016012
# 3    0.259615  0.084967  0.117904
# 4    0.346154  0.764706  0.007278
# ..        ...       ...       ...
# 115  0.375000  0.640523  0.042213
# 116  0.355769  0.294118  0.020378
# 117  0.557692  0.620915  0.002911
# 118  0.509615  0.993464  0.518195
# 119  0.298077  0.241830  0.013100
#
# [120 rows x 3 columns]

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LGBMRegressor(n_estimators=1000, random_state=1234)

# %%
subfeatures = ['title', 'box_off_num']
subfile = test[subfeatures]

# %%
singleGBM = subfile.copy()
singleGBM['box_off_num'] = model.predict(X_test_scaled)
singleGBM.to_csv('sigleGBM.csv', index=False)
print(singleGBM.tail(10))
print(singleGBM.shape)
# Out:
#             title   box_off_num
# 358         카운트다운  2.303088e+06
# 385           방독피 -4.015635e+04
# 334         폴라로이드 -4.311819e+04
# 170          폭풍전야  8.847622e+05
# 595            해무  1.687757e+06
# 144  어우동: 주인 없는 꽃  1.156630e+05
# 386           캐릭터 -2.460172e+04
# 437         나쁜 나라 -3.801796e+05
# 313   미안해 사랑해 고마워  1.712274e+06
# 471       뷰티풀 차일드 -2.363321e+04
# (120, 2)

# %%
from sklearn.model_selection import KFold
k_fold = KFold(n_splits=5, shuffle=True, random_state=1234)

# %%
model = lgb.LGBMRegressor(random_state=1234,n_estimators=1000)

models = []

for train_idx, val_idx in k_fold.split(X_train_scaled):
    x_t = X_train_scaled.iloc[train_idx]
    y_t = y_train.iloc[train_idx]
    x_val = X_train_scaled.iloc[val_idx]
    y_val = y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set=(x_val, y_val), early_stopping_rounds=100, verbose = 100))
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's l2: 1.76378e+12
# Early stopping, best iteration is:
# [17]	valid_0's l2: 1.54856e+12
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's l2: 2.08694e+12
# Early stopping, best iteration is:
# [31]	valid_0's l2: 1.94979e+12
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's l2: 1.78235e+12
# Early stopping, best iteration is:
# [12]	valid_0's l2: 1.29062e+12
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's l2: 4.97194e+12
# Early stopping, best iteration is:
# [22]	valid_0's l2: 4.3544e+12
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's l2: 2.14265e+12
# Early stopping, best iteration is:
# [24]	valid_0's l2: 1.97928e+12

# %%
preds = []

for model in models:
    preds.append(model.predict(X_test_scaled))
len(preds)
# Out:
# 5

# %%
import numpy as np

# %%
kFoldLightGBM = subfile.copy()
kFoldLightGBM['box_off_num'] = np.mean(preds, axis=0)
kFoldLightGBM.to_csv('kFoldLightGBM.csv', index=False)
kFoldLightGBM.tail()
# Out:
#             title   box_off_num
# 144  어우동: 주인 없는 꽃  5.483660e+04
# 386           캐릭터  6.279751e+04
# 437         나쁜 나라 -2.266383e+05
# 313   미안해 사랑해 고마워  2.165018e+06
# 471       뷰티풀 차일드  6.372460e+04

# %%
kFoldLightGBM['box_off_num']
# Out:
# 434    4.891317e+06
# 122    4.158138e+06
# 224    6.714817e+04
# 479    6.108375e+04
# 205    2.261120e+05
#            ...
# 144    5.483660e+04
# 386    6.279751e+04
# 437   -2.266383e+05
# 313    2.165018e+06
# 471    6.372460e+04
# Name: box_off_num, Length: 120, dtype: float64

# %%
y_predict = kFoldLightGBM['box_off_num']

# %%
from sklearn.metrics import mean_squared_error
def RMSE(y_test, y_predict):
    return np.sqrt(mean_squared_error(y_test, y_predict))
print('RMSE : ', RMSE(y_test, y_predict))
# Out:
# RMSE :  1346314.5883769987

# %%
from sklearn.metrics import r2_score
r2_y_predict = r2_score(y_test, y_predict)
print('R2 : ', r2_y_predict)
# Out:
# R2 :  0.35465843414913456

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = lgb.LGBMRegressor(random_state=1234, n_estimators=1000)


params = {
    'learning_rate': [0.1, 0.01, 0.003],
    'min_child_samples': [20, 30]}

gs = GridSearchCV(estimator=model,
            param_grid=params,
            scoring='neg_mean_squared_error',
            cv = k_fold)

# %%
gs.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1234, shuffle=True),
#              estimator=LGBMRegressor(n_estimators=1000, random_state=1234),
#              param_grid={'learning_rate': [0.1, 0.01, 0.003],
#                          'min_child_samples': [20, 30]},
#              scoring='neg_mean_squared_error')

# %%
gs.best_params_
# Out:
# {'learning_rate': 0.003, 'min_child_samples': 30}

# %%
model = lgb.LGBMRegressor(random_state=1234,n_estimators=1000, learning_rate=0.003, min_child_samples=30)

models = []

for train_idx, val_idx in k_fold.split(X_train_scaled):
    x_t = X_train_scaled.iloc[train_idx]
    y_t = y_train.iloc[train_idx]
    x_val = X_train_scaled.iloc[val_idx]
    y_val = y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set=(x_val, y_val), early_stopping_rounds=100, verbose = 0))

# %%
preds = []

for model in models:
    preds.append(model.predict(X_test_scaled))
len(preds)
# Out:
# 5

# %%
kFoldLightGBM = subfile.copy()
kFoldLightGBM['box_off_num'] = np.mean(preds, axis=0)
kFoldLightGBM.to_csv('kFoldLightGBM.csv', index=False)
kFoldLightGBM.tail()
# Out:
#             title   box_off_num
# 144  어우동: 주인 없는 꽃  6.942238e+04
# 386           캐릭터  6.816770e+04
# 437         나쁜 나라 -1.267505e+05
# 313   미안해 사랑해 고마워  2.072257e+06
# 471       뷰티풀 차일드  6.030576e+04

# %%
y_predict = kFoldLightGBM['box_off_num']

# %%
from sklearn.metrics import r2_score
r2_y_predict = r2_score(y_test, y_predict)
print('R2 : ', r2_y_predict)
# Out:
# R2 :  0.4262811353381619

# %%
from sklearn.metrics import mean_squared_error
def RMSE(y_test, y_predict):
    return np.sqrt(mean_squared_error(y_test, y_predict))
print('RMSE : ', RMSE(y_test, y_predict))
# Out:
# RMSE :  1269408.1948575869
